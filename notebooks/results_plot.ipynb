# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
evol_list = [0.4181, 0.42815, 0.4170, 0.4065, 0.4382, 0.4584, 0.4282, 0.4586, 0.4282, 0.43825, 0.4787, 0.4680, 0.4585, 0.4676, 0.4570]

# %%
plt.plot(evol_list)
plt.xlabel("Generation number", color = "r")
plt.ylabel("Fitness Score", color = "r")
plt.savefig("../assets/gen_scores.png", facecolor='white', transparent=False)

# %%
data = []
for line in open("../config/evol_chkpts/best.txt"):
    if line.strip():
        data.append(int(line))
len(data)
# Out:
# 1225

# %%
data[0]=1

# %%
plt.bar(list(range(1225)), data)
plt.savefig("../assets/bar.png", facecolor='white', transparent=False)

# %%
plot_with_precentage = [0.38, 0.392, 0.40, 0.43, 0.48, 0.45, 0.455, 0.445, 0.45, 0.43, 0.42, 0.43, 0.41, 0.4]
x = np.array((range(15, 29)))
plt.plot(x, plot_with_precentage)
plt.xlabel("Features Precentage ", color = "r")
plt.ylabel("Best Fitness Score", color = "r")
plt.savefig("../assets/best_score_vs_feature_precentage", facecolor='white', transparent=False)

# %%
train_acc = [0.49, 0.495, 0.498, 0.5, 0.53, 0.51, 0.54, 0.55, 0.555, 0.557, 0.587, 0.615, 0.645, 0.65, 0.6551, 0.655, 0.6552, 0.65812, 0.66, 0.665]
val_acc = [0.45, 0.465, 0.468, 0.51, 0.51, 0.50, 0.51, 0.51, 0.512, 0.51, 0.53, 0.55, 0.6, 0.61, 0.63, 0.635, 0.62, 0.61, 0.58, 0.579]

# %%
epochs = list(range(1,21))
plt.plot(epochs, train_acc, label = "TRAINING")
plt.plot(epochs, val_acc, label = "VALIDATION")
plt.xlabel("Epoch ", color = "r")
plt.ylabel("RECOGNITION SCORE", color = "r")
plt.legend()
plt.savefig("../assets/accuracies.png", facecolor='white', transparent=False)
